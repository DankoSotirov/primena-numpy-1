# %% [markdown]
# <a href="https://colab.research.google.com/github/DankoSotirov/primena-numpy-1/blob/main/python2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Treće vežbe iz pajtona. Blokovi. Kontrola toka, grananje. Korisnički definisane funkcije

# %% [markdown]
# 1. Izvršiti ćeliju ispod, a onda napisati kod u sledećoj ćeliji koji ispisuje "Polozio", ako je promenljiva *ocena* iznad 1,5 ili "Pao", ako je promenljiva *ocena* ispod 1,5.

# %%
ocena=3.14

# %%
# Primer promenljive ocena
ocena = 2.0  # možeš promeniti vrednost

# Provera ocene
if ocena > 1.5:
    print("Polozio")
else:
    print("Pao")
# Out:
# Polozio

# %% [markdown]
# 2. Napisati kod u ćeliju ispod koji u odnosu na ocenu ispisuje odgovarajući uspeh:
# - 4.5-5 odlican
# - 3.5-4.5 vrlo dobar
# - 2.5-3.5 dobar
# - 1.5-2.5 dovoljan
# - 0-1.5 nedovoljan

# %%
# Primer promenljive ocena
ocena = 3.8  # možeš promeniti vrednost

# Provera i ispis uspeha
if 4.5 <= ocena <= 5:
    print("odlican")
elif 3.5 <= ocena < 4.5:
    print("vrlo dobar")
elif 2.5 <= ocena < 3.5:
    print("dobar")
elif 1.5 <= ocena < 2.5:
    print("dovoljan")
elif 0 <= ocena < 1.5:
    print("nedovoljan")
else:
    print("Nevalidna ocena")
# Out:
# vrlo dobar

# %% [markdown]
# 3. Izvršiti kod u sledećoj ćeliji.

# %%
trazeni_uspeh=6.28/2

# %% [markdown]
# - Napisati kod u sledećoj ćeliji koji ispituje da li je ocena jednaka traženom uspehu, i ako jeste, ispisati: "Dostignut traženi uspeh"

# %%
# Primer promenljivih
ocena = 4.7  # trenutna ocena
trazeni_uspeh = "odlican"  # željeni uspeh

# Funkcija koja određuje uspeh prema oceni
def odredi_uspeh(ocena):
    if 4.5 <= ocena <= 5:
        return "odlican"
    elif 3.5 <= ocena < 4.5:
        return "vrlo dobar"
    elif 2.5 <= ocena < 3.5:
        return "dobar"
    elif 1.5 <= ocena < 2.5:
        return "dovoljan"
    elif 0 <= ocena < 1.5:
        return "nedovoljan"
    else:
        return "Nevalidna ocena"

# Provera da li je dostignut traženi uspeh
if odredi_uspeh(ocena) == trazeni_uspeh:
    print("Dostignut traženi uspeh")
# Out:
# Dostignut traženi uspeh

# %% [markdown]
# 4. Izvršiti sledeću ćeliju, pa onda napisati kod koji računa sumu, prosek i maksimum niza *a*.

# %%
a=[4,6,21,7.3,0.1]

# %%
# Suma niza
suma = sum(a)

# Prosek niza
prosek = sum(a) / len(a)

# Maksimum niza
maksimum = max(a)

print("Suma:", suma)
print("Prosek:", prosek)
print("Maksimum:", maksimum)
# Out:
# Suma: 38.4
# Prosek: 7.68
# Maksimum: 21

# %% [markdown]
# 5.
# - Ispisati svaki drugi element niza *a*.

# %%
print(a[1::2])
# Out:
# [6, 7.3]

# %% [markdown]
# - Napraviti novi niz *b*, koji sadrži duplirane elemente niza *a*
# - Napraviti novi niz *c*, koji sadrži polovljene elemente niza *a*.

# %%
# Niz sa dupliranim elementima
b = [x*2 for x in a]

# Niz sa polovljenim elementima
c = [x/2 for x in a]

print("Niz b (duplirani elementi):", b)
print("Niz c (polovljeni elementi):", c)
# Out:
# Niz b (duplirani elementi): [8, 12, 42, 14.6, 0.2]
# Niz c (polovljeni elementi): [2.0, 3.0, 10.5, 3.65, 0.05]

# %% [markdown]
# 6. Napraviti novi niz *d*, koji sadrži zbir odgovarajućih elemenata nizova *a*+*b*+*c*.

# %%
b = [x*2 for x in a]
c = [x/2 for x in a]

# Zbir odgovarajućih elemenata
d = [a[i] + b[i] + c[i] for i in range(len(a))]

print("Niz d (zbir elemenata a+b+c):", d)
# Out:
# Niz d (zbir elemenata a+b+c): [14.0, 21.0, 73.5, 25.549999999999997, 0.35000000000000003]

# %% [markdown]
# 7. Definisati funkciju koja duplira uneseni broj

# %%
def dupliraj(x):
    return x * 2

# Primer korišćenja
broj = 5
print(dupliraj(broj))  # Rezultat: 10
# Out:
# 10

# %% [markdown]
# 8. Definisati funkciju koja ispisuje odgovarajuću poruku u odnosu na argument ocena, nalik na 2. zadatak.

# %%
def ispisi_uspeh(ocena):
    if ocena < 1.5:
        print("nedovoljan")
    elif 1.5 <= ocena < 2.5:
        print("dovoljan")
    elif 2.5 <= ocena < 3.5:
        print("dobar")
    elif 3.5 <= ocena < 4.5:
        print("vrlo dobar")
    elif 4.5 <= ocena <= 5:
        print("odlican")
    else:
        print("Nevalidna ocena")

# Primer korišćenja
ispisi_uspeh(3.8)  # Rezultat: vrlo dobar
# Out:
# vrlo dobar

# %% [markdown]
# 9. Napisati funkciju *samoglasnici*, koja za prosleđen string ispisuje samo samoglasnike redom, npr. "Dobar dan, dragi gledaoci"-> "oa a ai eaoi"

# %%
def samoglasnici(s):
    # Definišemo samoglasnike
    glasnici = "aeiouAEIOU"
    # Izdvajamo samo samoglasnike iz stringa
    rezultat = "".join([c for c in s if c in glasnici])
    print(rezultat)

# Primer korišćenja
samoglasnici("Dobar dan, dragi gledaoci")  # Rezultat: "oa a ai eaoi"
# Out:
# oaaaieaoi

# %%
print(samoglasnici("Pajton je super"))
print(samoglasnici("trk"))
print(samoglasnici("  "))
print(samoglasnici("a"))
# Out:
# aoeue
# None
#
# None
#
# None
# a
# None
